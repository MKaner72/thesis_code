# %% [markdown]
# # Graphs from MatLab

# %%
from scipy.optimize import curve_fit
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
def lorentzian(x, amp, ctr, wid):
    return amp*wid**2/((x-ctr)**2+wid**2)

# %% [markdown]
# Importing the data from a csv file.

# %%
index_of_refraction = pd.read_csv(r"Index_of_refraction_CSV_file.csv")
electric_field = pd.read_csv(r"E-field_CSV_file.csv")
transmission = pd.read_csv(r"transmission_spectrum_from_MatLab.csv")

# %%
#Plotting (Full Spectrum)
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)

transmission.plot(ax=ax)

# Set the color of the lines to black
for line in ax.get_lines():
    line.set_color('black')

ax.set_xlabel("Wavelength (nm)", fontsize=35, labelpad=20)
ax.set_ylabel("Transmission (%)", fontsize=35, labelpad=20)

labels = ['Transmission']
ax.legend(labels=labels, fontsize='xx-large', loc=(0.78, 0.90))
#plt.xticks(fontsize=30)
#plt.yticks(fontsize=30)

# Customize tick parameters
ax.tick_params(axis='both',       # Apply to both x and y axes
               direction='in', # Tick direction (inside)
               length=10,         # Length of ticks
               width=2,           # Width of ticks
               colors='black')    

# Customize minor tick parameters
ax.tick_params(axis='both',       # Apply to both x and y axes
               which='minor',    # Minor ticks
               direction='in',   # Tick direction (inside)
               length=5,         # Length of minor ticks
               width=2,          # Width of minor ticks
               colors='black')   # Color of minor ticks

ax.minorticks_on()
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')

ax.tick_params(top="on", bottom="on", right="on", left="on")

ax.spines['bottom'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)

# Setting custom tick marks and labels for x-axis
custom_xticklabels = ['', '500', '600', '700', '800', '900', '1000'] 
ax.set_xticklabels(custom_xticklabels, fontsize=30)

# Setting custom tick marks and labels for y-axis
custom_yticklabels = ['','0', '20', '40', '60', '80']  
ax.set_yticklabels(custom_yticklabels, fontsize=30)

#Saving the figure
plt.savefig('Cavity_Transmission_MatLab_Design.png', dpi=500, transparent=False, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/s2/hl_85_4n61xcr2235_6_039c0000gn/T/ipykernel_5968/1709879325.py:47: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(custom_xticklabels, fontsize=30)
# /var/folders/s2/hl_85_4n61xcr2235_6_039c0000gn/T/ipykernel_5968/1709879325.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(custom_yticklabels, fontsize=30)

# %%
#Plotting index of refraction and electric field
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)

index_of_refraction.plot(ax=ax, color='black')
electric_field.plot(ax=ax, color='red')

labels = ['Index of Refraction', 'Electric Field |E|^2 (arbitrary units)']
ax.legend(labels=labels, fontsize='xx-large', loc=(0.55, 0.80))

ax.set_xlabel("Distance ($\mu m$)", fontsize=35, labelpad=20)
ax.set_ylabel("Refractive Index", fontsize=35, labelpad=20)

# Customize tick parameters
ax.tick_params(axis='both',       # Apply to both x and y axes
               direction='in', # Tick direction (inside)
               length=10,         # Length of ticks
               width=2,           # Width of ticks
               colors='black')    

# Customize minor tick parameters
ax.tick_params(axis='both',       # Apply to both x and y axes
               which='minor',    # Minor ticks
               direction='in',   # Tick direction (inside)
               length=5,         # Length of minor ticks
               width=2,          # Width of minor ticks
               colors='black')   # Color of minor ticks

ax.minorticks_on()
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')

ax.tick_params(top="on", bottom="on", right="on", left="on")

ax.spines['bottom'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)

plt.xticks(fontsize=30)
plt.yticks(fontsize=30)

# Setting custom tick marks and labels for x-axis
custom_xticklabels = ['', '0', '1', '2', '3', '4', '5'] 
ax.set_xticklabels(custom_xticklabels, fontsize=30)

#Saving the figure
plt.savefig('Cavity_Electric_Field_MatLab_Design.png', dpi=500, transparent=False, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/s2/hl_85_4n61xcr2235_6_039c0000gn/T/ipykernel_5968/2118751864.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(custom_xticklabels, fontsize=30)

# %% [markdown]
# Importing data for the DBR Mirror

# %%
index_of_refraction_bragg = pd.read_csv(r"index_of_refraction_Bragg_FIXED_CSV.csv")
electric_field_bragg = pd.read_csv(r"electric_field_magnitude_Bragg_ATTEMPT_TWO.csv")
transmission_bragg = pd.read_csv(r"transmission_spectrum_Bragg .csv")

# %%
#Plotting (Full Spectrum for DBR)
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)

transmission_bragg.plot(ax=ax)

# Set the color of the lines to black
for line in ax.get_lines():
    line.set_color('black')

ax.set_xlabel("Wavelength (nm)", fontsize=35, labelpad=20)
ax.set_ylabel("Transmission (%)", fontsize=35, labelpad=20)

labels = ['Transmission']
ax.legend(labels=labels, fontsize='xx-large', loc=(0.78, 0.90))
#plt.xticks(fontsize=30)
#plt.yticks(fontsize=30)

# Customize tick parameters
ax.tick_params(axis='both',       # Apply to both x and y axes
               direction='in', # Tick direction (inside)
               length=10,         # Length of ticks
               width=2,           # Width of ticks
               colors='black')    

# Customize minor tick parameters
ax.tick_params(axis='both',       # Apply to both x and y axes
               which='minor',    # Minor ticks
               direction='in',   # Tick direction (inside)
               length=5,         # Length of minor ticks
               width=2,          # Width of minor ticks
               colors='black')   # Color of minor ticks

ax.minorticks_on()
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')

ax.tick_params(top="on", bottom="on", right="on", left="on")

ax.spines['bottom'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)

# Setting custom tick marks and labels for x-axis
custom_xticklabels = ['', '500', '600', '700', '800', '900', '1000'] 
ax.set_xticklabels(custom_xticklabels, fontsize=30)

# Setting custom tick marks and labels for y-axis
custom_yticklabels = ['','0', '20', '40', '60', '80', '100']  
ax.set_yticklabels(custom_yticklabels, fontsize=30)

#Saving the figure
plt.savefig('Transmission_MatLab_Design_BRAGG.png', dpi=500, transparent=False, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/s2/hl_85_4n61xcr2235_6_039c0000gn/T/ipykernel_5968/1896050127.py:47: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(custom_xticklabels, fontsize=30)
# /var/folders/s2/hl_85_4n61xcr2235_6_039c0000gn/T/ipykernel_5968/1896050127.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(custom_yticklabels, fontsize=30)

# %%
#Plotting index of refraction and electric field for DBR
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)

index_of_refraction_bragg.plot(ax=ax, color='black')
electric_field_bragg.plot(ax=ax, color='red')

labels = ['Index of Refraction', 'Electric Field |E|^2 (arbitrary units)']
ax.legend(labels=labels, fontsize='xx-large', loc=(0.53, 0.86))

ax.set_xlabel("Distance ($\mu m$)", fontsize=35, labelpad=20)
ax.set_ylabel("Refractive Index", fontsize=35, labelpad=20)

# Customize tick parameters
ax.tick_params(axis='both',       # Apply to both x and y axes
               direction='in', # Tick direction (inside)
               length=10,         # Length of ticks
               width=2,           # Width of ticks
               colors='black')    

# Customize minor tick parameters
ax.tick_params(axis='both',       # Apply to both x and y axes
               which='minor',    # Minor ticks
               direction='in',   # Tick direction (inside)
               length=5,         # Length of minor ticks
               width=2,          # Width of minor ticks
               colors='black')   # Color of minor ticks

ax.minorticks_on()
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')

ax.tick_params(top="on", bottom="on", right="on", left="on")

ax.spines['bottom'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)

plt.xticks(fontsize=30)
plt.yticks(fontsize=30)

# Setting custom tick marks and labels for x-axis
custom_xticklabels = ['', '0', '1', '2', '3', '4', '5'] 
ax.set_xticklabels(custom_xticklabels, fontsize=30)

#Saving the figure
plt.savefig('Cavity_Electric_Field_MatLab_Design_BRAGG.png', dpi=500, transparent=False, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/s2/hl_85_4n61xcr2235_6_039c0000gn/T/ipykernel_5968/3557773495.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(custom_xticklabels, fontsize=30)

# %% [markdown]
# Now the graphs for the empty cavity.

# %%
index_of_refraction_cavity = pd.read_csv(r"index_of_refraction_Empty_Cavity.csv")
electric_field_cavity = pd.read_csv(r"electric_field_magnitude_Empty_Cavity.csv")
transmission_cavity = pd.read_csv(r"transmission_spectrum_Empty_Cavity 2.csv")

# %%
#Plotting (Full Spectrum for Cavity)
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)

transmission_cavity.plot(ax=ax)

# Set the color of the lines to black
for line in ax.get_lines():
    line.set_color('black')

ax.set_xlabel("Wavelength (nm)", fontsize=35, labelpad=20)
ax.set_ylabel("Transmission (%)", fontsize=35, labelpad=20)

labels = ['Transmission']
ax.legend(labels=labels, fontsize='xx-large', loc=(0.78, 0.90))
#plt.xticks(fontsize=30)
#plt.yticks(fontsize=30)

# Customize tick parameters
ax.tick_params(axis='both',       # Apply to both x and y axes
               direction='in', # Tick direction (inside)
               length=10,         # Length of ticks
               width=2,           # Width of ticks
               colors='black')    

# Customize minor tick parameters
ax.tick_params(axis='both',       # Apply to both x and y axes
               which='minor',    # Minor ticks
               direction='in',   # Tick direction (inside)
               length=5,         # Length of minor ticks
               width=2,          # Width of minor ticks
               colors='black')   # Color of minor ticks

ax.minorticks_on()
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')

ax.tick_params(top="on", bottom="on", right="on", left="on")

ax.spines['bottom'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)

# Setting custom tick marks and labels for x-axis
custom_xticklabels = ['', '500', '600', '700', '800', '900', '1000'] 
ax.set_xticklabels(custom_xticklabels, fontsize=30)

# Setting custom tick marks and labels for y-axis
custom_yticklabels = ['','0', '20', '40', '60', '80', '100']  
ax.set_yticklabels(custom_yticklabels, fontsize=30)

#Saving the figure
plt.savefig('Transmission_MatLab_Design_Cavity.png', dpi=500, transparent=False, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/s2/hl_85_4n61xcr2235_6_039c0000gn/T/ipykernel_5968/2067597406.py:47: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(custom_xticklabels, fontsize=30)
# /var/folders/s2/hl_85_4n61xcr2235_6_039c0000gn/T/ipykernel_5968/2067597406.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(custom_yticklabels, fontsize=30)

# %%
#Plotting index of refraction and electric field for Cavity
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)

electric_field_cavity = (electric_field_cavity * 0.002) + 1.5

index_of_refraction_cavity.plot(ax=ax, color='black')
electric_field_cavity.plot(ax=ax, color='red')

labels = ['Index of Refraction', 'Electric Field |E|^2 (arbitrary units)']
ax.legend(labels=labels, fontsize='xx-large', loc=(0.53, 0.86))

ax.set_xlabel("Distance ($\mu m$)", fontsize=35, labelpad=20)
ax.set_ylabel("Refractive Index", fontsize=35, labelpad=20)

# Customize tick parameters
ax.tick_params(axis='both',       # Apply to both x and y axes
               direction='in', # Tick direction (inside)
               length=10,         # Length of ticks
               width=2,           # Width of ticks
               colors='black')    

# Customize minor tick parameters
ax.tick_params(axis='both',       # Apply to both x and y axes
               which='minor',    # Minor ticks
               direction='in',   # Tick direction (inside)
               length=5,         # Length of minor ticks
               width=2,          # Width of minor ticks
               colors='black')   # Color of minor ticks

ax.minorticks_on()
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')

ax.tick_params(top="on", bottom="on", right="on", left="on")

ax.spines['bottom'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)

plt.xticks(fontsize=30)
plt.yticks(fontsize=30)

# Setting custom tick marks and labels for x-axis
custom_xticklabels = ['', '0', '1', '2', '3', '4', '5'] 
ax.set_xticklabels(custom_xticklabels, fontsize=30)

#Saving the figure
plt.savefig('Cavity_Electric_Field_MatLab_Design_Cavity.png', dpi=500, transparent=False, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/s2/hl_85_4n61xcr2235_6_039c0000gn/T/ipykernel_5968/50115981.py:47: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(custom_xticklabels, fontsize=30)
